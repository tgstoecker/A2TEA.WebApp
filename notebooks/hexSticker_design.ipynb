# %% [markdown]
# ## Installation & Setup

# %%
#install r-magick and r-curl via conda!
#using sudo apt-get will not work unless you connect imagemagick and curl manually (don't do this...)
#install.packages("hexSticker")
#install.packages("ggplot2")

# %%
library(hexSticker)
library(ggplot2)

# %%
#?sticker

# %%
#p <- hist(rnorm(100))
p <- ggplot(aes(x = mpg, y = wt), data = mtcars) + geom_point()
p <- p + theme_void() + theme_transparent()

sticker(p, 
        package="hexSticker", 
        p_size=20, 
        s_x=1, 
        s_y=.75, 
        s_width=1.3, 
        s_height=1,
        filename="baseplot.png")

# %%
library(showtext)
## Loading Google fonts (http://www.google.com/fonts)
font_add_google("Exo 2", "exo2")
## Automatically use showtext to render text for future devices
showtext_auto()

# %%
sticker(subplot = "logo/logo_idea_3_v1.png",
        s_x = 1,	
        s_y = 0.85,
        s_width = 0.6,
        s_height = 0.5,
        package="A2TEA",
        p_size=100,
        p_color = "#F39C12", 
        p_x = 1,
        p_y = 1.6,
        p_family = "exo2", 
        p_fontface = ,
#        h_size = ,
#        h_fill = ,
        h_color = "#F39C12",
        url = "tgstoecker/A2TEA",
        u_size = 25,
        #u_x = ,
        #u_y = ,
        u_color = "#F39C12",
        u_family = "exo2",
        #u_angle = 
#        s_x=1, 
#        s_y=.75, 
#        s_width=.6,
        filename="a2tea_hexsticker.png",
        dpi = 1500)

# %%
?sticker
# Out:
# sticker               package:hexSticker               R Documentation
#
# r
#
# n:
#
#      create sticker in R
#
# e:
#
#      sticker(
#        subplot,
#        s_x = 0.8,
#        s_y = 0.75,
#        s_width = 0.4,
#        s_height = 0.5,
#        package,
#        p_x = 1,
#        p_y = 1.4,
#        p_color = "#FFFFFF",
#        p_family = "Aller_Rg",
#        p_fontface = "plain",
#        p_size = 8,
#        h_size = 1.2,
#        h_fill = "#1881C2",
#        h_color = "#87B13F",
#        spotlight = FALSE,
#        l_x = 1,
#        l_y = 0.5,
#        l_width = 3,
#        l_height = 3,
#        l_alpha = 0.4,
#        url = "",
#        u_x = 1,
#        u_y = 0.08,
#        u_color = "black",
#        u_family = "Aller_Rg",
#        u_size = 1.5,
#        u_angle = 30,
#        white_around_sticker = FALSE,
#        ...,
#        filename = paste0(package, ".png"),
#        asp = 1,
#        dpi = 300
#      )
#
# s:
#
#  subplot: subplot
#
# ...
